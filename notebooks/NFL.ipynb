# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

print(Path.cwd())
#received error code csv not found, use this to see where python is pulling from and noticed i saved it the wrong folder
# Out:
# /Users/jakieldavid/Repos/applied-ml-Jakiel/notebooks

# %%
df = pd.read_csv("team_stats_2003_2023.csv")
print(df.head())
# Out:
#    year                  team  wins  losses  win_loss_perc  points  \
# 0  2003  New England Patriots    14       2          0.875     348
# 1  2003        Miami Dolphins    10       6          0.625     311
# 2  2003         Buffalo Bills     6      10          0.375     243
# 3  2003         New York Jets     6      10          0.375     283
# 4  2003      Baltimore Ravens    10       6          0.625     391
#
#    points_opp  points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  \
# 0         238          110  6.9  16  ...        9               3.4       91
# 1         261           50  3.1  16  ...       14               3.7       99
# 2         279          -36 -2.3  16  ...       13               3.9       96
# 3         299          -16 -1.0  16  ...        8               4.0       78
# 4         281          110  6.9  16  ...       18               4.8      115
#
#    penalties  penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  \
# ...

# %%
df.columns.tolist()
# Out:
# ['year',
#  'team',
#  'wins',
#  'losses',
#  'win_loss_perc',
#  'points',
#  'points_opp',
#  'points_diff',
#  'mov',
#  'g',
#  'total_yards',
#  'plays_offense',
#  'yds_per_play_offense',
#  'turnovers',
#  'fumbles_lost',
#  'first_down',
#  'pass_cmp',
#  'pass_att',
#  'pass_yds',
#  'pass_td',
#  'pass_int',
#  'pass_net_yds_per_att',
#  'pass_fd',
#  'rush_att',
#  'rush_yds',
#  'rush_td',
#  'rush_yds_per_att',
#  'rush_fd',
#  'penalties',
#  'penalties_yds',
#  'pen_fd',
#  'score_pct',
#  'turnover_pct',
#  'exp_pts_tot',
#  'ties']

# %%
#creating histograms for relevant columns/features
columns_to_plot = [
    "pass_yds",
    "pass_td",
    "pass_att",
    "pass_cmp",
]
plt.figure(figsize=(12, 8))
for i, col in enumerate(columns_to_plot, 1):
    plt.subplot(3, 2, i)
    plt.hist(df[col], bins=15, color="red", edgecolor="black")
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel

plt.tight_layout()
plt.show()

# %%
df[["pass_yds", "pass_td", "pass_att", "pass_cmp", "wins"]].isna().sum()
# Out:
# pass_yds    0
# pass_td     0
# pass_att    0
# pass_cmp    0
# wins        0
# dtype: int64

# %%
plt.hist(df["wins"], bins=15, color="red", edgecolor="black")
plt.title("Histogram of Wins")
plt.xlabel("Wins")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
plt.hist(df["pass_td"], bins=15, color="green", edgecolor="black")
plt.title("Histogram of Passing Touchdowns")
plt.xlabel("Passing Touchdowns")
plt.ylabel("Frequency")
plt.show()
plt.tight_layout()
plt.show()
